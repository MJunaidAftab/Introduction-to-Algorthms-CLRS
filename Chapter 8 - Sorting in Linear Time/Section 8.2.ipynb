# %%
def Counting_Sort(A,k):
    
    #We assume each input is an integer between 0 and k. Hence there are a totalof k + 1 possibilities for
    #each entry.
    
    C = []
    B = []
    
    n = len(A)
    print(A)
    
    for i in range(k+1):
        C.append(0)
    
    for j in range(n):
        B.append(0)   
        C[A[j]] = C[A[j]] + 1
        
    print(C)   
    print('------------------------------------------------------------------------------------------')
        
    #C[i] now contains the number of elements equal to i  
    
    for i in range(1,k+1):
        
        C[i] = C[i] + C[i-1]
        
    print(C)
    print('------------------------------------------------------------------------------------------')
    
    #C[i] now contains the number of elements less than or equal to i.   
    
    for j in range(n-1,-1,-1):
        
        B[C[A[j]]-1] = A[j]
        C[A[j]] = C[A[j]] - 1
        
        print(B)
        print(C)
        print('------------------------------------------------------------------------------------------')
        
    return B

# %%
A = [1,40,50,13,41]
B = Counting_Sort(A,50)
print(B)
# Out:
# [1, 13, 40, 41, 50]

# %% [markdown]
# ### 8.2.1

# %%
A = [6,0,2,0,1,3,4,6,1,3,2]
B = Counting_Sort(A,6)
print(B)
# Out:
# [6, 0, 2, 0, 1, 3, 4, 6, 1, 3, 2]
# [2, 2, 2, 2, 1, 0, 2]
# ------------------------------------------------------------------------------------------
# [2, 4, 6, 8, 9, 9, 11]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 0, 0, 2, 0, 0, 0, 0, 0]
# [2, 4, 5, 8, 9, 9, 11]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 0, 0, 2, 0, 3, 0, 0, 0]
# [2, 4, 5, 7, 9, 9, 11]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 1, 0, 2, 0, 3, 0, 0, 0]
# [2, 3, 5, 7, 9, 9, 11]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 1, 0, 2, 0, 3, 0, 0, 6]
# [2, 3, 5, 7, 9, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 1, 0, 2, 0, 3, 4, 0, 6]
# [2, 3, 5, 7, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 0, 1, 0, 2, 3, 3, 4, 0, 6]
# [2, 3, 5, 6, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 0, 2, 3, 3, 4, 0, 6]
# [2, 2, 5, 6, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 0, 2, 3, 3, 4, 0, 6]
# [1, 2, 5, 6, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 0, 6]
# [1, 2, 4, 6, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 0, 6]
# [0, 2, 4, 6, 8, 9, 10]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 6, 6]
# [0, 2, 4, 6, 8, 9, 9]
# ------------------------------------------------------------------------------------------
# [0, 0, 1, 1, 2, 2, 3, 3, 4, 6, 6]

# %% [markdown]
# ### 8.2.2
