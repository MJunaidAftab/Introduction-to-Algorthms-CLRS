# %% [markdown]
# # Problem 1
#
# ## Part (a)
#
# There are $n!$ possible permutations of the input array assuming all input elements are distinct. Each permutation is in a different leaf since the algorithm needs to perfectly distinguish between two distinct permutations Since each permutation is equally likely, so, each occurs with probability $\frac{1}{n!}$.
#
# ## Part(b)
#
# The depths of particular elements of in the left and right subtrees are all one less than their depths when considered elements of the original tree. Also the left and right subtrees form a partition of all the leaves of the decision tree. This effectively proves the statement.
#
# ## Part(c)
#
# Suppose we have a decision tree with $k$ leaves. If $i$ is the number of leaves in the left subtree, we have $D(T) = D(LT) + D(RT) + k$. Now take the minimum value of $D(T)$ over all decision trees to yield the desired result.
#
# ## Part(d)
#
# We can minimize this function using calculus. The lower bound follows easily.
#
# ## Part(e)
#
# We have $n!$ leaves. Therefore a lower bound on the external length is $n! \lg n!$. The average case time is ( n! \lg n! ) / n! = \lg (n!) = \Theta ( n \lg n )$.
#
# ## Part(f)
#
# Since the expected runtime is the average over all possible results from the random bits, if every possible fixing of the randomness resulted in a higher runtime, the average would have to be higher as well.
#
#
# # Problem 2
#
# ## Part (a)
#
# Counting sort.
#
# ## Part (b)
#
# Quicksort-Partition.
#
# ## Part (c)
#
# Insertion sort.
#
# ## Part (d)
#
# Yes, no, no.
#
#
# # Problem 4
#
# ## Part (a)
#
# Select a red jug. Compare it to blue jugs until you find one which matches. Set that pair aside, and repeat for the next red jug.
#
# ## Part (b)
#
# We can imagine first lining up the red jugs in some order. Then a solution to this problem becomes a permutation of the blue jugs such that the iith blue jug is the same size as the iith red jug. As in section 8.1, we can make a decision tree which represents comparisons made between blue jugs and red jugs. An internal node represents a comparison between a specific pair of red and blue jugs, and a leaf node represents a permutation of the blue jugs based on the results of the comparison. We are interested in when one jug is greater than, less than, or equal in size to another jug, so the tree should have 33 children per node.
#
# ## Part (c)
#
#  We use an algorithm analogous to randomized quicksort. Select a blue jug at random. Partition the red jugs into those which are smaller than the blue jug, and those which are larger. At some point in the comparisons, you will find the red jug which is of equal size. Once the red jugs have been divided by size, use the red jug of equal size to partition the blue jugs into those which are smaller and those which are larger. If $k$ red jugs are smaller than the originally chosen jug, we need to solve the original problem on input of size $k − 1$ and size $n − k$, which we will do in the same manner.
#
# # Problem 5
#
# ## Part(a)
#
# Sorted in the usual sense.
#
# ## Part(b)
#
# 3,1,4,2,6,5,8,7,9,10.
#
# ## Part(c)
#
# This is clear.
#
# ## Part(d)
#
# No idea.
#
# ## Part(e)
#
# Using a heap, we can sort a $k$-sorted array of length nn in $O(n\lg k)$ time.
#
# ## Part(f)
#
# The lower bound of sorting each part is $ \Omega(n / k\lg(n / k))$, so the total lower bound is $\Theta(n\lg (n/k))$. Since $k$ is a constant, therefore $\Theta(n\lg(n / k)) = \Omega(n\lg n)$.
#
# # Problem 5
#
# ## Part(a)
#
# $\binom{2n}{n}$
#
# ## Part(b)
#
# The decision tree must have $\binom{2n}{n}$ nodes. We then have,
#
# $$
# $\binom{2n}{n}$ \leq 2^h
# \quad
# \Longleftrightarrow
# \quad
# h \geq \frac{\lg (2n)!}{\lg n!}
# \quad
# \Longleftrightarrow
# \quad
# h \geq \Theta ( 2n \lg n ) - 2 \Theta ( n \lg n )
# \quad
# \Longleftrightarrow
# \quad
# h \geq \Theta ( 2n \lg 2 n ) - 2 \Theta ( n \lg n )
# = \Theta (2n).
# $$
#
# ## Part(c)
#
# We have to know the order of the two consecutive elements.
#
# ## Part(d)
#
# Consider lists $1,3,5,\cdots, 2n-1$ and $2,4,6,\cdots,2n$.
